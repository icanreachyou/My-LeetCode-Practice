# %% [markdown]
# # 3.无重复字符的最长子串

# %% [markdown]
# Leetcode第一次尝试，结果稍显逊色，跟大佬还是有很大差距。

# %% [markdown]
# ## 3.1题目描述

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 3.2对比结果

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 3.3我的代码

# %%
class Solution:
    def lengthOfLongestSubstring(self, s: str) -> int:
        s_list = list(s)
        temp = 0
        for i in range(len(s_list)):
            re = []
            re.append(s_list[i])
            for j in range(i+1, len(s_list)):
                if s_list[j] not in re:
                    re.append(s_list[j])
                elif s_list[j] in re:
                    break
            if len(re)>temp:
                temp = len(re)
        return temp

# %% [markdown]
# ## 3.4官方代码

# %%
class Solution:
    def lengthOfLongestSubstring(self, s: str) -> int:
        # 哈希集合，记录每个字符是否出现过
        occ = set()
        n = len(s)
        # 右指针，初始值为 -1，相当于我们在字符串的左边界的左侧，还没有开始移动
        rk, ans = -1, 0
        for i in range(n):
            if i != 0:
                # 左指针向右移动一格，移除一个字符
                occ.remove(s[i - 1])
            while rk + 1 < n and s[rk + 1] not in occ:
                # 不断地移动右指针
                occ.add(s[rk + 1])
                rk += 1
            # 第 i 到 rk 个字符是一个极长的无重复字符子串
            ans = max(ans, rk - i + 1)
        return ans

# 作者：LeetCode-Solution
# 链接：https://leetcode-cn.com/problems/longest-substring-without-repeating-characters/solution/wu-zhong-fu-zi-fu-de-zui-chang-zi-chuan-by-leetc-2/
# 来源：力扣（LeetCode）
# 著作权归作者所有。商业转载请联系作者获得授权，非商业转载请注明出处。

# %% [markdown]
# ## 3.5回顾

# %% [markdown]
# 1.无重复，集合比列表更好
#
# 2.考虑无穷的情况
#
# 3.优化循环，降低时间复杂度
