# %% [markdown]
# # 7.整数反转

# %% [markdown]
# ## 7.1题目描述

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 7.2对比结果

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 7.3我的代码

# %%
class Solution:
    def reverse(self, x: int) -> int:
        x_abs = abs(x)
        temp_list = []
        temp = 0
        while x_abs >= 1:
            temp_list.append(x_abs % 10) 
            x_abs = int(x_abs/10) 
        for i in range(len(temp_list)):
            temp = temp + temp_list[i]*10**(len(temp_list)-i-1)
        if x < 0:
            temp = -temp
        # 判断反转后的整数是否超过范围
        if (temp < -2**31) or (temp > 2**31-1):
            temp = 0
        return temp

# %% [markdown]
# ## 7.4官方代码

# %%
class Solution:
    def reverse(self, x: int) -> int:
        INT_MIN, INT_MAX = -2**31, 2**31 - 1

        rev = 0
        while x != 0:
            # INT_MIN 也是一个负数，不能写成 rev < INT_MIN // 10
            if rev < INT_MIN // 10 + 1 or rev > INT_MAX // 10:
                return 0
            digit = x % 10
            # Python3 的取模运算在 x 为负数时也会返回 [0, 9) 以内的结果，因此这里需要进行特殊判断
            if x < 0 and digit > 0:
                digit -= 10

            # 同理，Python3 的整数除法在 x 为负数时会向下（更小的负数）取整，因此不能写成 x //= 10
            x = (x - digit) // 10
            rev = rev * 10 + digit
        
        return rev

# 作者：LeetCode-Solution
# 链接：https://leetcode-cn.com/problems/reverse-integer/solution/zheng-shu-fan-zhuan-by-leetcode-solution-bccn/
# 来源：力扣（LeetCode）
# 著作权归作者所有。商业转载请联系作者获得授权，非商业转载请注明出处。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 居然比官方代码要好一点ouo

# %% [markdown]
# ## 7.5回顾

# %% [markdown]
# 1.一开始被这个整数的限制条件给吓到了，以为要处理计算机的数据编码，后来仔细思考过之后发现还是比较适合我这种初学者的。
#
# 2.评论区大佬有用java写的程序，看上去是真的高效，值得借鉴。
