# %% [markdown]
# # 剑指Offer 09. 用两个栈实现队列

# %% [markdown]
# ## 1.问题描述

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 2.对比结果

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 3.我的代码

# %%
# .pop() 移除列表中的一个元素（默认是最后一个），并返回该元素的值。

class CQueue:

    def __init__(self):
        self.stack_add = []
        self.stack_del = []

    def appendTail(self, value: int) -> None:
        self.stack_add.append(value)

    def deleteHead(self) -> int:
        if self.stack_del:
            return self.stack_del.pop()
        if not self.stack_add:
            return -1
        while self.stack_add:
            self.stack_del.append(self.stack_add.pop())
        return self.stack_del.pop()
        
# Your CQueue object will be instantiated and called as such:
# obj = CQueue()
# obj.appendTail(value)
# param_2 = obj.deleteHead()

# %% [markdown]
# ## 4.官方代码

# %% [markdown]
# 官方代码未给出python示例

# %% [markdown]
# ## 5.回顾

# %% [markdown]
# 第一次做这种带有数据结构的题，在python的函数技巧上还是有待提高的，.pop()这个函数是我百度之后才知道的，后面还看到了.insert()
